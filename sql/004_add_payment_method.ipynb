# %%
# %sql
ALTER TABLE workspace.landing.orders
ADD COLUMNS (
    payment_method STRING
);

ALTER TABLE workspace.bronze.orders
ADD COLUMNS (
    payment_method STRING
);

ALTER TABLE workspace.silver.orders
ADD COLUMNS (
    payment_method STRING
);

ALTER TABLE workspace.gold.orders
ADD COLUMNS (
    payment_method STRING
);
