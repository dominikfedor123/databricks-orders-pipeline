# %%
# %sql
ALTER TABLE workspace.silver.orders
ADD COLUMNS (
    dq_order_date INT,
    dq_currency INT
);

# %%
# %sql
ALTER TABLE workspace.control.rejected_orders
ADD COLUMNS (
    currency_raw STRING,
    currency_clean STRING
);
